# %%
import numpy as np # for random number distributions
import pandas as pd # for event_log data frame
pd.set_option('display.max_rows', 20)
pd.set_option('display.max_columns', 10)
import queue # add FIFO queue data structure
from functools import partial, wraps

import simpy # discrete event simulation environment

# %%
#set available resources
machine1 = 3

min_machine1_time = 5 #minutes (300 seconds)
mean_machine1_time = 10 #minutes (600 seconds)
max_machine1_time = 20 #minutes (1200 seconds)

mean_prep_time = 3 #minutes (900 seconds)

inventory1_queue_length = 20 #max amount of parts in queue before send to inventory

inv1 = 0 #prepared parts inventory for stage 1 machining

#available resources for line 2
machine2 = 2

min_machine2_time = 10 #minutes (600 seconds)
mean_machine2_time = 20 #minutes (1200 seconds)
max_machine2_time = 30 #minutes (1800 seconds)

inventory2_queue_length = 30 #max amount of parts in queue before send to inventory for stage 2

inv2 = 0

obtain_reproducible_results = True

#set length of simulation
simulation_days = 1
fixed_simulation_time = simulation_days*16*60*60 #16 operating hours from two 8 hour shifts

parameter_string_list = [str(simulation_days), 'days',
                        str(machine1),str(min_machine1_time),
                        str(mean_machine1_time),str(max_machine1_time),
                        str(mean_prep_time),str(inventory1_queue_length),
                        str(machine2),str(min_machine2_time),
                        str(mean_machine2_time),str(max_machine2_time),
                        str(inventory2_queue_length)]
separator = '-'
simulation_file_identifier = separator.join(parameter_string_list)

#initialize queue 1 length
#queue1 = 0

# %%
#function that generates random times for the 1st machining process
def random_machine1_time(min_machine1_time,mean_machine1_time,max_machine1_time):
    try_machine1_time = np.random.exponential(scale = mean_machine1_time)
    if (try_machine1_time < min_machine1_time):
        return(min_machine1_time)
    if (try_machine1_time > max_machine1_time):
        return(max_machine1_time)
    if (try_machine1_time >= min_machine1_time) and (try_machine1_time <= max_machine1_time):
        return(try_machine1_time)

# %%
#function that generates random times for the 2nd machining process
def random_machine2_time(min_machine2_time,mean_machine2_time,max_machine2_time):
    try_machine2_time = np.random.exponential(scale = mean_machine2_time)
    if (try_machine2_time < min_machine2_time):
        return(min_machine2_time)
    if (try_machine2_time > max_machine2_time):
        return(max_machine2_time)
    if (try_machine2_time >= min_machine2_time) and (try_machine2_time <= max_machine2_time):
        return(try_machine2_time)

# %%
#generates the prepped parts for the beginning of the process
def prep(env, caseid, caseid_queue1, caseid_inv1, event_log):
    #generates new parts prepared for machine stage 1
    caseid = 0
    while True:
        
        prep_time = round(60*np.random.exponential(scale = mean_prep_time))
        
        print("Next prepared part for Stage 1: ", env.now + prep_time)
        
        yield env.timeout(prep_time)
        
        caseid += 1
        time = env.now
        activity = 'prep_part'
        env.process(event_log_append(env, caseid, time, activity, event_log))
        yield env.timeout(0)
        
        #if-else statement determines if the prepared part should be stored in inventory or the machining queue
        if caseid_queue1.qsize() < inventory1_queue_length:
            caseid_queue1.put(caseid)
            print("Prepared part joins queue caseid =",caseid,'time =',env.now,'queue_length =',caseid_queue1.qsize())
            time = env.now
            activity = 'join_queue1'
            env.process(event_log_append(env, caseid, time, activity, event_log))
            env.process(machine1_process(env, caseid_queue1, event_log))
        else:
            caseid_inv1.put(caseid)
            print("Prepared part placed in Stage 1 Inventory. caseid=", caseid,'time =',env.now,'inv_size =',caseid_inv1.qsize())
            env.process(event_log_append(env, caseid, env.now, 'inv1', event_log))

# %%
#function for the 1st machining process
def machine1_process(env, caseid_queue, event_log):
    #must have available stage 1 machines
    with available_machine1.request() as req:
        yield req
        
        #if-else determines if we should be using inventory parts or queued parts
        #to follow first-in-first-out processes will need to modify this to fill the back of the queue when a spot opens up
        if caseid_inv1.qsize() > 0:
            queue1_length_on_entering_machining = caseid_inv1.qsize()
            caseid = caseid_inv1.get()
            print("Begin_stage1_machining for inventory parts, caseid =",caseid,'time = ',env.now,'inv1_length =', queue1_length_on_entering_machining)
            env.process(event_log_append(env, caseid, env.now, 'begin_stage1_machine', event_log))
            machine1_time = round(60*random_machine1_time(min_machine1_time,mean_machine1_time,max_machine1_time))
            yield env.timeout(machine1_time)
            queue1_length_on_leaving_machining = caseid_inv1.qsize()
            print("End_stage1_machining for inventory parts caseid=",caseid,'time = ',env.now,'queue1_length =',queue1_length_on_leaving_machining)
            env.process(event_log_append(env, caseid, env.now, 'end_stage1_machine', event_log))

            
        else:
            queue1_length_on_entering_machining = caseid_queue1.qsize()
            caseid = caseid_queue1.get()
            print("Begin_stage1_machining caseid =",caseid,'time = ',env.now,'queue1_length =',queue1_length_on_entering_machining)
            env.process(event_log_append(env, caseid, env.now, 'begin_stage1_machine', event_log))
            machine1_time = round(60*random_machine1_time(min_machine1_time,mean_machine1_time,max_machine1_time))
            yield env.timeout(machine1_time)
            queue1_length_on_leaving_machining = caseid_queue.qsize()
            print("End_stage1_machining caseid=",caseid,'time = ',env.now,'queue1_length =',queue1_length_on_leaving_machining)
            env.process(event_log_append(env, caseid, env.now, 'end_stage1_machine', event_log))

        #this puts the finished part into a transitional queue that we then pass to the next machining process
        caseid_transition.put(caseid)
        print("Transition to stage 2 caseid=",caseid,'time = ',env.now,'transition_queue_length =',caseid_transition.qsize())
        env.process(event_log_append(env, caseid, env.now, 'transition', event_log))
        env.process(machine2_process(env, caseid_transition, event_log))

# %%
#function for the 2nd machining process
def machine2_process(env, caseid_queue, event_log):
    #initializes the caseid with the transitional queue value that we pass from the 1st machine process
    caseid = caseid_transition.get()
    
    #if-else determines if we should place the machined part into inventory or the machining queue
    if caseid_queue2.qsize() < inventory2_queue_length:
        caseid_queue2.put(caseid)
        print("Machined part joins queue2 caseid =",caseid,'time =',env.now,'queue_length =',caseid_queue2.qsize())
        time = env.now
        activity = 'join_queue2'
        env.process(event_log_append(env, caseid, time, activity, event_log))
    else:
        caseid_inv2.put(caseid)
        print("Machined part placed in Stage 2 Inventory. caseid=", caseid,'time =',env.now,'inv_size =',caseid_inv2.qsize())
        env.process(event_log_append(env, caseid, env.now, 'inv2', event_log))
    
    with available_machine2.request() as req:
        yield req
      
        #if-else determines if we should use the inventory or the queue parts
        #will need to make adjustment that is noted in the first machining process about first-in-first-out
        if caseid_inv2.qsize() > 0:
            queue2_length_on_entering_machining = caseid_inv2.qsize()
            caseid = caseid_inv2.get()
            print("Begin_stage2_machining for inventory parts, caseid =",caseid,'time = ',env.now,'inv2_length =', queue2_length_on_entering_machining)
            env.process(event_log_append(env, caseid, env.now, 'begin_stage2_machine', event_log))
            machine2_time = round(60*random_machine2_time(min_machine2_time,mean_machine2_time,max_machine2_time))
            yield env.timeout(machine2_time)
            queue2_length_on_leaving_machining = caseid_inv2.qsize()
            print("End_stage2_machining for inventory parts caseid=",caseid,'time = ',env.now,'queue2_length =',queue2_length_on_leaving_machining)
            env.process(event_log_append(env, caseid, env.now, 'end_stage2_machine', event_log))
            
        else:
            queue2_length_on_entering_machining = caseid_queue2.qsize()
            caseid = caseid_queue2.get()
            print("Begin_stage2_machining caseid =",caseid,'time = ',env.now,'queue2_length =',queue2_length_on_entering_machining)
            env.process(event_log_append(env, caseid, env.now, 'begin_stage2_machine', event_log))
            machine2_time = round(60*random_machine2_time(min_machine2_time,mean_machine2_time,max_machine2_time))
            yield env.timeout(machine2_time)
            queue2_length_on_leaving_machining = caseid_queue.qsize()
            print("End_stage2_machining caseid=",caseid,'time = ',env.now,'queue2_length =',queue2_length_on_leaving_machining)
            env.process(event_log_append(env, caseid, env.now, 'end_stage2_machine', event_log))

# %%
def trace(env, callback):
     """Replace the ``step()`` method of *env* with a tracing function
     that calls *callbacks* with an events time, priority, ID and its
     instance just before it is processed.
     note: "event" here refers to simulaiton program events

     """
     def get_wrapper(env_step, callback):
         """Generate the wrapper for env.step()."""
         @wraps(env_step)
         def tracing_step():
             """Call *callback* for the next event if one exist before
             calling ``env.step()``."""
             if len(env._queue):
                 t, prio, eid, event = env._queue[0]
                 callback(t, prio, eid, event)
             return env_step()
         return tracing_step

     env.step = get_wrapper(env.step, callback)

def trace_monitor(data, t, prio, eid, event):
     data.append((t, eid, type(event)))

def test_process(env):
     yield env.timeout(1)

# %%
def event_log_append(env, caseid, time, activity, event_log):
    event_log.append((caseid, time, activity))
    yield env.timeout(0)

# %%
if obtain_reproducible_results:
    np.random.seed(9999)

#set up simulation trace monitoring
data = []
#bind data as first argument to monitor)
this_trace_monitor = partial(trace_monitor, data)

env = simpy.Environment()
trace(env, this_trace_monitor)

env.process(test_process(env))

#hold caseid values
caseid_queue1 = queue.Queue()
caseid_inv1 = queue.Queue()
caseid_queue2 = queue.Queue()
caseid_inv2 = queue.Queue()
caseid_transition = queue.Queue()

#setup limited stage 1 machines
available_machine1 = simpy.Resource(env, capacity = machine1)
available_machine2 = simpy.Resource(env, capacity = machine2)
caseid = -1

event_log = [(caseid,0,'null_start_simulation')]
env.process(event_log_append(env, caseid, env.now, 'start_simulation', event_log))

env.process(prep(env, caseid, caseid_queue1, caseid_inv1, event_log))

env.run(until = fixed_simulation_time)
# Out:
# Next prepared part for Stage 1:  312
# Prepared part joins queue caseid = 1 time = 312 queue_length = 1
# Next prepared part for Stage 1:  356
# Begin_stage1_machining caseid = 1 time =  312 queue1_length = 1
# Prepared part joins queue caseid = 2 time = 356 queue_length = 1
# Next prepared part for Stage 1:  498
# Begin_stage1_machining caseid = 2 time =  356 queue1_length = 1
# Prepared part joins queue caseid = 3 time = 498 queue_length = 1
# Next prepared part for Stage 1:  535
# Begin_stage1_machining caseid = 3 time =  498 queue1_length = 1
# Prepared part joins queue caseid = 4 time = 535 queue_length = 1
# Next prepared part for Stage 1:  702
# End_stage1_machining caseid= 1 time =  612 queue1_length = 1
# Transition to stage 2 caseid= 1 time =  612 transition_queue_length = 1
# Machined part joins queue2 caseid = 1 time = 612 queue_length = 1
# Begin_stage2_machining caseid = 1 time =  612 queue2_length = 1
# Begin_stage1_machining caseid = 4 time =  612 queue1_length = 1
# End_stage1_machining caseid= 2 time =  656 queue1_length = 0
# Transition to stage 2 caseid= 2 time =  656 transition_queue_length = 1
# Machined part joins queue2 caseid = 2 time = 656 queue_length = 1
# Begin_stage2_machining caseid = 2 time =  656 queue2_length = 1
# Prepared part joins queue caseid = 5 time = 702 queue_length = 1
# Next prepared part for Stage 1:  967
# Begin_stage1_machining caseid = 5 time =  702 queue1_length = 1
# End_stage1_machining caseid= 3 time =  827 queue1_length = 0
# Transition to stage 2 caseid= 3 time =  827 transition_queue_length = 1
# Machined part joins queue2 caseid = 3 time = 827 queue_length = 1
# Prepared part joins queue caseid = 6 time = 967 queue_length = 1
# Next prepared part for Stage 1:  1064
# Begin_stage1_machining caseid = 6 time =  967 queue1_length = 1
# End_stage1_machining caseid= 5 time =  1002 queue1_length = 0
# Transition to stage 2 caseid= 5 time =  1002 transition_queue_length = 1
# Machined part joins queue2 caseid = 5 time = 1002 queue_length = 2
# Prepared part joins queue caseid = 7 time = 1064 queue_length = 1
# Next prepared part for Stage 1:  1146
# Begin_stage1_machining caseid = 7 time =  1064 queue1_length = 1
# Prepared part joins queue caseid = 8 time = 1146 queue_length = 1
# Next prepared part for Stage 1:  1302
# End_stage1_machining caseid= 4 time =  1232 queue1_length = 1
# Transition to stage 2 caseid= 4 time =  1232 transition_queue_length = 1
# Machined part joins queue2 caseid = 4 time = 1232 queue_length = 3
# Begin_stage1_machining caseid = 8 time =  1232 queue1_length = 1
# End_stage1_machining caseid= 6 time =  1267 queue1_length = 0
# Transition to stage 2 caseid= 6 time =  1267 transition_queue_length = 1
# Machined part joins queue2 caseid = 6 time = 1267 queue_length = 4
# Prepared part joins queue caseid = 9 time = 1302 queue_length = 1
# Next prepared part for Stage 1:  1373
# Begin_stage1_machining caseid = 9 time =  1302 queue1_length = 1
# End_stage1_machining caseid= 7 time =  1364 queue1_length = 0
# Transition to stage 2 caseid= 7 time =  1364 transition_queue_length = 1
# Machined part joins queue2 caseid = 7 time = 1364 queue_length = 5
# Prepared part joins queue caseid = 10 time = 1373 queue_length = 1
# Next prepared part for Stage 1:  1406
# Begin_stage1_machining caseid = 10 time =  1373 queue1_length = 1
# Prepared part joins queue caseid = 11 time = 1406 queue_length = 1
# Next prepared part for Stage 1:  1550
# End_stage2_machining caseid= 1 time =  1426 queue2_length = 0
# Begin_stage2_machining caseid = 3 time =  1426 queue2_length = 5
# End_stage1_machining caseid= 8 time =  1532 queue1_length = 1
# Transition to stage 2 caseid= 8 time =  1532 transition_queue_length = 1
# Machined part joins queue2 caseid = 8 time = 1532 queue_length = 5
# Begin_stage1_machining caseid = 11 time =  1532 queue1_length = 1
# Prepared part joins queue caseid = 12 time = 1550 queue_length = 1
# Next prepared part for Stage 1:  1665
# Prepared part joins queue caseid = 13 time = 1665 queue_length = 2
# Next prepared part for Stage 1:  2027
# End_stage1_machining caseid= 10 time =  1768 queue1_length = 2
# Transition to stage 2 caseid= 10 time =  1768 transition_queue_length = 1
# Machined part joins queue2 caseid = 10 time = 1768 queue_length = 6
# Begin_stage1_machining caseid = 12 time =  1768 queue1_length = 2
# End_stage1_machining caseid= 11 time =  1875 queue1_length = 1
# Transition to stage 2 caseid= 11 time =  1875 transition_queue_length = 1
# Machined part joins queue2 caseid = 11 time = 1875 queue_length = 7
# Begin_stage1_machining caseid = 13 time =  1875 queue1_length = 1
# Prepared part joins queue caseid = 14 time = 2027 queue_length = 1
# Next prepared part for Stage 1:  2100
# Prepared part joins queue caseid = 15 time = 2100 queue_length = 2
# Next prepared part for Stage 1:  2257
# End_stage1_machining caseid= 12 time =  2231 queue1_length = 2
# Transition to stage 2 caseid= 12 time =  2231 transition_queue_length = 1
# Machined part joins queue2 caseid = 12 time = 2231 queue_length = 8
# Begin_stage1_machining caseid = 14 time =  2231 queue1_length = 2
# Prepared part joins queue caseid = 16 time = 2257 queue_length = 2
# Next prepared part for Stage 1:  2399
# End_stage1_machining caseid= 13 time =  2273 queue1_length = 2
# Transition to stage 2 caseid= 13 time =  2273 transition_queue_length = 1
# Machined part joins queue2 caseid = 13 time = 2273 queue_length = 9
# Begin_stage1_machining caseid = 15 time =  2273 queue1_length = 2
# Prepared part joins queue caseid = 17 time = 2399 queue_length = 2
# Next prepared part for Stage 1:  2673
# End_stage1_machining caseid= 9 time =  2451 queue1_length = 2
# Transition to stage 2 caseid= 9 time =  2451 transition_queue_length = 1
# Machined part joins queue2 caseid = 9 time = 2451 queue_length = 10
# Begin_stage1_machining caseid = 16 time =  2451 queue1_length = 2
# End_stage2_machining caseid= 2 time =  2456 queue2_length = 0
# Begin_stage2_machining caseid = 5 time =  2456 queue2_length = 10
# End_stage2_machining caseid= 3 time =  2533 queue2_length = 0
# Begin_stage2_machining caseid = 4 time =  2533 queue2_length = 9
# Prepared part joins queue caseid = 18 time = 2673 queue_length = 2
# Next prepared part for Stage 1:  2719
# Prepared part joins queue caseid = 19 time = 2719 queue_length = 3
# Next prepared part for Stage 1:  2731
# Prepared part joins queue caseid = 20 time = 2731 queue_length = 4
# Next prepared part for Stage 1:  2743
# Prepared part joins queue caseid = 21 time = 2743 queue_length = 5
# Next prepared part for Stage 1:  2863
# Prepared part joins queue caseid = 22 time = 2863 queue_length = 6
# Next prepared part for Stage 1:  2866
# Prepared part joins queue caseid = 23 time = 2866 queue_length = 7
# Next prepared part for Stage 1:  3048
# End_stage1_machining caseid= 14 time =  2913 queue1_length = 7
# Transition to stage 2 caseid= 14 time =  2913 transition_queue_length = 1
# Machined part joins queue2 caseid = 14 time = 2913 queue_length = 9
# Begin_stage1_machining caseid = 17 time =  2913 queue1_length = 7
# Prepared part joins queue caseid = 24 time = 3048 queue_length = 7
# Next prepared part for Stage 1:  3311
# End_stage2_machining caseid= 5 time =  3056 queue2_length = 0
# Begin_stage2_machining caseid = 6 time =  3056 queue2_length = 9
# End_stage1_machining caseid= 16 time =  3195 queue1_length = 7
# Transition to stage 2 caseid= 16 time =  3195 transition_queue_length = 1
# Machined part joins queue2 caseid = 16 time = 3195 queue_length = 9
# Begin_stage1_machining caseid = 18 time =  3195 queue1_length = 7
# Prepared part joins queue caseid = 25 time = 3311 queue_length = 7
# Next prepared part for Stage 1:  3734
# End_stage1_machining caseid= 15 time =  3473 queue1_length = 7
# Transition to stage 2 caseid= 15 time =  3473 transition_queue_length = 1
# Machined part joins queue2 caseid = 15 time = 3473 queue_length = 10
# Begin_stage1_machining caseid = 19 time =  3473 queue1_length = 7
# End_stage1_machining caseid= 18 time =  3495 queue1_length = 6
# Transition to stage 2 caseid= 18 time =  3495 transition_queue_length = 1
# Machined part joins queue2 caseid = 18 time = 3495 queue_length = 11
# Begin_stage1_machining caseid = 20 time =  3495 queue1_length = 6
# End_stage1_machining caseid= 17 time =  3549 queue1_length = 5
# Transition to stage 2 caseid= 17 time =  3549 transition_queue_length = 1
# Machined part joins queue2 caseid = 17 time = 3549 queue_length = 12
# Begin_stage1_machining caseid = 21 time =  3549 queue1_length = 5
# End_stage2_machining caseid= 6 time =  3656 queue2_length = 0
# Begin_stage2_machining caseid = 7 time =  3656 queue2_length = 12
# Prepared part joins queue caseid = 26 time = 3734 queue_length = 5
# Next prepared part for Stage 1:  3860
# End_stage1_machining caseid= 19 time =  3773 queue1_length = 5
# Transition to stage 2 caseid= 19 time =  3773 transition_queue_length = 1
# Machined part joins queue2 caseid = 19 time = 3773 queue_length = 12
# Begin_stage1_machining caseid = 22 time =  3773 queue1_length = 5
# Prepared part joins queue caseid = 27 time = 3860 queue_length = 5
# Next prepared part for Stage 1:  3966
# End_stage1_machining caseid= 21 time =  3958 queue1_length = 5
# Transition to stage 2 caseid= 21 time =  3958 transition_queue_length = 1
# Machined part joins queue2 caseid = 21 time = 3958 queue_length = 13
# Begin_stage1_machining caseid = 23 time =  3958 queue1_length = 5
# Prepared part joins queue caseid = 28 time = 3966 queue_length = 5
# Next prepared part for Stage 1:  4243
# End_stage1_machining caseid= 20 time =  4016 queue1_length = 5
# Transition to stage 2 caseid= 20 time =  4016 transition_queue_length = 1
# Machined part joins queue2 caseid = 20 time = 4016 queue_length = 14
# Begin_stage1_machining caseid = 24 time =  4016 queue1_length = 5
# Prepared part joins queue caseid = 29 time = 4243 queue_length = 5
# Next prepared part for Stage 1:  4268
# End_stage1_machining caseid= 23 time =  4258 queue1_length = 5
# Transition to stage 2 caseid= 23 time =  4258 transition_queue_length = 1
# Machined part joins queue2 caseid = 23 time = 4258 queue_length = 15
# Begin_stage1_machining caseid = 25 time =  4258 queue1_length = 5
# Prepared part joins queue caseid = 30 time = 4268 queue_length = 5
# Next prepared part for Stage 1:  4439
# End_stage2_machining caseid= 4 time =  4333 queue2_length = 0
# Begin_stage2_machining caseid = 8 time =  4333 queue2_length = 15
# Prepared part joins queue caseid = 31 time = 4439 queue_length = 6
# Next prepared part for Stage 1:  4819
# End_stage1_machining caseid= 22 time =  4440 queue1_length = 6
# Transition to stage 2 caseid= 22 time =  4440 transition_queue_length = 1
# Machined part joins queue2 caseid = 22 time = 4440 queue_length = 15
# Begin_stage1_machining caseid = 26 time =  4440 queue1_length = 6
# End_stage1_machining caseid= 25 time =  4558 queue1_length = 5
# Transition to stage 2 caseid= 25 time =  4558 transition_queue_length = 1
# Machined part joins queue2 caseid = 25 time = 4558 queue_length = 16
# Begin_stage1_machining caseid = 27 time =  4558 queue1_length = 5
# Prepared part joins queue caseid = 32 time = 4819 queue_length = 5
# Next prepared part for Stage 1:  4966
# End_stage2_machining caseid= 8 time =  4933 queue2_length = 0
# Begin_stage2_machining caseid = 10 time =  4933 queue2_length = 16
# Prepared part joins queue caseid = 33 time = 4966 queue_length = 6
# Next prepared part for Stage 1:  5146
# Prepared part joins queue caseid = 34 time = 5146 queue_length = 7
# Next prepared part for Stage 1:  5190
# Prepared part joins queue caseid = 35 time = 5190 queue_length = 8
# Next prepared part for Stage 1:  5240
# End_stage1_machining caseid= 24 time =  5216 queue1_length = 8
# Transition to stage 2 caseid= 24 time =  5216 transition_queue_length = 1
# Machined part joins queue2 caseid = 24 time = 5216 queue_length = 16
# Begin_stage1_machining caseid = 28 time =  5216 queue1_length = 8
# Prepared part joins queue caseid = 36 time = 5240 queue_length = 8
# Next prepared part for Stage 1:  5247
# Prepared part joins queue caseid = 37 time = 5247 queue_length = 9
# Next prepared part for Stage 1:  5394
# Prepared part joins queue caseid = 38 time = 5394 queue_length = 10
# Next prepared part for Stage 1:  5537
# End_stage2_machining caseid= 7 time =  5456 queue2_length = 0
# Begin_stage2_machining caseid = 11 time =  5456 queue2_length = 16
# End_stage1_machining caseid= 28 time =  5516 queue1_length = 10
# Transition to stage 2 caseid= 28 time =  5516 transition_queue_length = 1
# Machined part joins queue2 caseid = 28 time = 5516 queue_length = 16
# Begin_stage1_machining caseid = 29 time =  5516 queue1_length = 10
# End_stage2_machining caseid= 10 time =  5533 queue2_length = 0
# Begin_stage2_machining caseid = 12 time =  5533 queue2_length = 16
# Prepared part joins queue caseid = 39 time = 5537 queue_length = 10
# Next prepared part for Stage 1:  5614
# End_stage1_machining caseid= 27 time =  5575 queue1_length = 10
# Transition to stage 2 caseid= 27 time =  5575 transition_queue_length = 1
# Machined part joins queue2 caseid = 27 time = 5575 queue_length = 16
# Begin_stage1_machining caseid = 30 time =  5575 queue1_length = 10
# Prepared part joins queue caseid = 40 time = 5614 queue_length = 10
# Next prepared part for Stage 1:  5728
# End_stage1_machining caseid= 26 time =  5640 queue1_length = 10
# Transition to stage 2 caseid= 26 time =  5640 transition_queue_length = 1
# Machined part joins queue2 caseid = 26 time = 5640 queue_length = 17
# Begin_stage1_machining caseid = 31 time =  5640 queue1_length = 10
# Prepared part joins queue caseid = 41 time = 5728 queue_length = 10
# Next prepared part for Stage 1:  5808
# Prepared part joins queue caseid = 42 time = 5808 queue_length = 11
# Next prepared part for Stage 1:  5877
# End_stage1_machining caseid= 29 time =  5816 queue1_length = 11
# Transition to stage 2 caseid= 29 time =  5816 transition_queue_length = 1
# Machined part joins queue2 caseid = 29 time = 5816 queue_length = 18
# Begin_stage1_machining caseid = 32 time =  5816 queue1_length = 11
# End_stage1_machining caseid= 30 time =  5875 queue1_length = 10
# Transition to stage 2 caseid= 30 time =  5875 transition_queue_length = 1
# Machined part joins queue2 caseid = 30 time = 5875 queue_length = 19
# Begin_stage1_machining caseid = 33 time =  5875 queue1_length = 10
# Prepared part joins queue caseid = 43 time = 5877 queue_length = 10
# Next prepared part for Stage 1:  6312
# End_stage2_machining caseid= 11 time =  6056 queue2_length = 0
# Begin_stage2_machining caseid = 13 time =  6056 queue2_length = 19
# End_stage1_machining caseid= 32 time =  6116 queue1_length = 10
# Transition to stage 2 caseid= 32 time =  6116 transition_queue_length = 1
# Machined part joins queue2 caseid = 32 time = 6116 queue_length = 19
# Begin_stage1_machining caseid = 34 time =  6116 queue1_length = 10
# End_stage2_machining caseid= 12 time =  6133 queue2_length = 0
# Begin_stage2_machining caseid = 9 time =  6133 queue2_length = 19
# End_stage1_machining caseid= 33 time =  6175 queue1_length = 9
# Transition to stage 2 caseid= 33 time =  6175 transition_queue_length = 1
# Machined part joins queue2 caseid = 33 time = 6175 queue_length = 19
# Begin_stage1_machining caseid = 35 time =  6175 queue1_length = 9
# End_stage1_machining caseid= 31 time =  6185 queue1_length = 8
# Transition to stage 2 caseid= 31 time =  6185 transition_queue_length = 1
# Machined part joins queue2 caseid = 31 time = 6185 queue_length = 20
# Begin_stage1_machining caseid = 36 time =  6185 queue1_length = 8
# Prepared part joins queue caseid = 44 time = 6312 queue_length = 8
# Next prepared part for Stage 1:  6422
# Prepared part joins queue caseid = 45 time = 6422 queue_length = 9
# Next prepared part for Stage 1:  6552
# End_stage1_machining caseid= 35 time =  6475 queue1_length = 9
# Transition to stage 2 caseid= 35 time =  6475 transition_queue_length = 1
# Machined part joins queue2 caseid = 35 time = 6475 queue_length = 21
# Begin_stage1_machining caseid = 37 time =  6475 queue1_length = 9
# End_stage1_machining caseid= 34 time =  6487 queue1_length = 8
# Transition to stage 2 caseid= 34 time =  6487 transition_queue_length = 1
# Machined part joins queue2 caseid = 34 time = 6487 queue_length = 22
# Begin_stage1_machining caseid = 38 time =  6487 queue1_length = 8
# End_stage1_machining caseid= 36 time =  6517 queue1_length = 7
# Transition to stage 2 caseid= 36 time =  6517 transition_queue_length = 1
# Machined part joins queue2 caseid = 36 time = 6517 queue_length = 23
# Begin_stage1_machining caseid = 39 time =  6517 queue1_length = 7
# Prepared part joins queue caseid = 46 time = 6552 queue_length = 7
# Next prepared part for Stage 1:  6656
# End_stage2_machining caseid= 13 time =  6656 queue2_length = 0
# Prepared part joins queue caseid = 47 time = 6656 queue_length = 8
# Next prepared part for Stage 1:  6725
# Begin_stage2_machining caseid = 14 time =  6656 queue2_length = 23
# Prepared part joins queue caseid = 48 time = 6725 queue_length = 9
# Next prepared part for Stage 1:  6731
# Prepared part joins queue caseid = 49 time = 6731 queue_length = 10
# Next prepared part for Stage 1:  6844
# Prepared part joins queue caseid = 50 time = 6844 queue_length = 11
# Next prepared part for Stage 1:  6888
# End_stage2_machining caseid= 9 time =  6887 queue2_length = 0
# Begin_stage2_machining caseid = 16 time =  6887 queue2_length = 22
# Prepared part joins queue caseid = 51 time = 6888 queue_length = 12
# Next prepared part for Stage 1:  7164
# Prepared part joins queue caseid = 52 time = 7164 queue_length = 13
# Next prepared part for Stage 1:  7288
# End_stage2_machining caseid= 14 time =  7256 queue2_length = 0
# Begin_stage2_machining caseid = 15 time =  7256 queue2_length = 21
# Prepared part joins queue caseid = 53 time = 7288 queue_length = 14
# Next prepared part for Stage 1:  7387
# End_stage1_machining caseid= 39 time =  7315 queue1_length = 14
# Transition to stage 2 caseid= 39 time =  7315 transition_queue_length = 1
# Machined part joins queue2 caseid = 39 time = 7315 queue_length = 21
# Begin_stage1_machining caseid = 40 time =  7315 queue1_length = 14
# Prepared part joins queue caseid = 54 time = 7387 queue_length = 14
# Next prepared part for Stage 1:  7528
# End_stage2_machining caseid= 16 time =  7487 queue2_length = 0
# Begin_stage2_machining caseid = 18 time =  7487 queue2_length = 21
# End_stage1_machining caseid= 37 time =  7502 queue1_length = 14
# Transition to stage 2 caseid= 37 time =  7502 transition_queue_length = 1
# Machined part joins queue2 caseid = 37 time = 7502 queue_length = 21
# Begin_stage1_machining caseid = 41 time =  7502 queue1_length = 14
# Prepared part joins queue caseid = 55 time = 7528 queue_length = 14
# Next prepared part for Stage 1:  7662
# End_stage1_machining caseid= 38 time =  7589 queue1_length = 14
# Transition to stage 2 caseid= 38 time =  7589 transition_queue_length = 1
# Machined part joins queue2 caseid = 38 time = 7589 queue_length = 22
# Begin_stage1_machining caseid = 42 time =  7589 queue1_length = 14
# End_stage1_machining caseid= 40 time =  7615 queue1_length = 13
# Transition to stage 2 caseid= 40 time =  7615 transition_queue_length = 1
# Machined part joins queue2 caseid = 40 time = 7615 queue_length = 23
# Begin_stage1_machining caseid = 43 time =  7615 queue1_length = 13
# Prepared part joins queue caseid = 56 time = 7662 queue_length = 13
# Next prepared part for Stage 1:  8057
# End_stage1_machining caseid= 41 time =  7802 queue1_length = 13
# Transition to stage 2 caseid= 41 time =  7802 transition_queue_length = 1
# Machined part joins queue2 caseid = 41 time = 7802 queue_length = 24
# Begin_stage1_machining caseid = 44 time =  7802 queue1_length = 13
# End_stage2_machining caseid= 15 time =  7856 queue2_length = 0
# Begin_stage2_machining caseid = 17 time =  7856 queue2_length = 24
# End_stage1_machining caseid= 42 time =  7889 queue1_length = 12
# Transition to stage 2 caseid= 42 time =  7889 transition_queue_length = 1
# Machined part joins queue2 caseid = 42 time = 7889 queue_length = 24
# Begin_stage1_machining caseid = 45 time =  7889 queue1_length = 12
# Prepared part joins queue caseid = 57 time = 8057 queue_length = 12
# Next prepared part for Stage 1:  8239
# End_stage1_machining caseid= 45 time =  8189 queue1_length = 12
# Transition to stage 2 caseid= 45 time =  8189 transition_queue_length = 1
# Machined part joins queue2 caseid = 45 time = 8189 queue_length = 25
# Begin_stage1_machining caseid = 46 time =  8189 queue1_length = 12
# Prepared part joins queue caseid = 58 time = 8239 queue_length = 12
# Next prepared part for Stage 1:  8270
# Prepared part joins queue caseid = 59 time = 8270 queue_length = 13
# Next prepared part for Stage 1:  8296
# Prepared part joins queue caseid = 60 time = 8296 queue_length = 14
# Next prepared part for Stage 1:  8675
# End_stage1_machining caseid= 44 time =  8343 queue1_length = 14
# Transition to stage 2 caseid= 44 time =  8343 transition_queue_length = 1
# Machined part joins queue2 caseid = 44 time = 8343 queue_length = 26
# Begin_stage1_machining caseid = 47 time =  8343 queue1_length = 14
# End_stage1_machining caseid= 46 time =  8489 queue1_length = 13
# Transition to stage 2 caseid= 46 time =  8489 transition_queue_length = 1
# Machined part joins queue2 caseid = 46 time = 8489 queue_length = 27
# Begin_stage1_machining caseid = 48 time =  8489 queue1_length = 13
# Prepared part joins queue caseid = 61 time = 8675 queue_length = 13
# Next prepared part for Stage 1:  8676
# Prepared part joins queue caseid = 62 time = 8676 queue_length = 14
# Next prepared part for Stage 1:  8772
# Prepared part joins queue caseid = 63 time = 8772 queue_length = 15
# Next prepared part for Stage 1:  8777
# Prepared part joins queue caseid = 64 time = 8777 queue_length = 16
# Next prepared part for Stage 1:  8827
# End_stage1_machining caseid= 43 time =  8815 queue1_length = 16
# Transition to stage 2 caseid= 43 time =  8815 transition_queue_length = 1
# Machined part joins queue2 caseid = 43 time = 8815 queue_length = 28
# Begin_stage1_machining caseid = 49 time =  8815 queue1_length = 16
# Prepared part joins queue caseid = 65 time = 8827 queue_length = 16
# Next prepared part for Stage 1:  9007
# End_stage2_machining caseid= 18 time =  8936 queue2_length = 0
# Begin_stage2_machining caseid = 19 time =  8936 queue2_length = 28
# End_stage2_machining caseid= 17 time =  8983 queue2_length = 0
# Begin_stage2_machining caseid = 21 time =  8983 queue2_length = 27
# Prepared part joins queue caseid = 66 time = 9007 queue_length = 17
# Next prepared part for Stage 1:  9133
# End_stage1_machining caseid= 47 time =  9085 queue1_length = 17
# Transition to stage 2 caseid= 47 time =  9085 transition_queue_length = 1
# Machined part joins queue2 caseid = 47 time = 9085 queue_length = 27
# Begin_stage1_machining caseid = 50 time =  9085 queue1_length = 17
# End_stage1_machining caseid= 49 time =  9119 queue1_length = 16
# Transition to stage 2 caseid= 49 time =  9119 transition_queue_length = 1
# Machined part joins queue2 caseid = 49 time = 9119 queue_length = 28
# Begin_stage1_machining caseid = 51 time =  9119 queue1_length = 16
# Prepared part joins queue caseid = 67 time = 9133 queue_length = 16
# Next prepared part for Stage 1:  9278
# Prepared part joins queue caseid = 68 time = 9278 queue_length = 17
# Next prepared part for Stage 1:  9339
# Prepared part joins queue caseid = 69 time = 9339 queue_length = 18
# Next prepared part for Stage 1:  9615
# End_stage1_machining caseid= 48 time =  9401 queue1_length = 18
# Transition to stage 2 caseid= 48 time =  9401 transition_queue_length = 1
# Machined part joins queue2 caseid = 48 time = 9401 queue_length = 29
# Begin_stage1_machining caseid = 52 time =  9401 queue1_length = 18
# End_stage1_machining caseid= 51 time =  9498 queue1_length = 17
# Transition to stage 2 caseid= 51 time =  9498 transition_queue_length = 1
# Machined part joins queue2 caseid = 51 time = 9498 queue_length = 30
# Begin_stage1_machining caseid = 53 time =  9498 queue1_length = 17
# End_stage1_machining caseid= 50 time =  9540 queue1_length = 16
# Transition to stage 2 caseid= 50 time =  9540 transition_queue_length = 1
# Machined part placed in Stage 2 Inventory. caseid= 50 time = 9540 inv_size = 1
# Begin_stage1_machining caseid = 54 time =  9540 queue1_length = 16
# Prepared part joins queue caseid = 70 time = 9615 queue_length = 16
# Next prepared part for Stage 1:  9821
# End_stage2_machining caseid= 19 time =  9627 queue2_length = 0
# Begin_stage2_machining for inventory parts, caseid = 50 time =  9627 inv2_length = 1
# Prepared part joins queue caseid = 71 time = 9821 queue_length = 17
# Next prepared part for Stage 1:  9896
# End_stage1_machining caseid= 52 time =  9855 queue1_length = 17
# Transition to stage 2 caseid= 52 time =  9855 transition_queue_length = 1
# Machined part placed in Stage 2 Inventory. caseid= 52 time = 9855 inv_size = 1
# Begin_stage1_machining caseid = 55 time =  9855 queue1_length = 17
# Prepared part joins queue caseid = 72 time = 9896 queue_length = 17
# Next prepared part for Stage 1:  10335
# End_stage1_machining caseid= 53 time =  10013 queue1_length = 17
# Transition to stage 2 caseid= 53 time =  10013 transition_queue_length = 1
# Machined part placed in Stage 2 Inventory. caseid= 53 time = 10013 inv_size = 2
# Begin_stage1_machining caseid = 56 time =  10013 queue1_length = 17
# End_stage1_machining caseid= 55 time =  10155 queue1_length = 16
# Transition to stage 2 caseid= 55 time =  10155 transition_queue_length = 1
# Machined part placed in Stage 2 Inventory. caseid= 55 time = 10155 inv_size = 3
# Begin_stage1_machining caseid = 57 time =  10155 queue1_length = 16
# End_stage2_machining caseid= 21 time =  10173 queue2_length = 0
# Begin_stage2_machining for inventory parts, caseid = 52 time =  10173 inv2_length = 3
# End_stage1_machining caseid= 56 time =  10313 queue1_length = 15
# Transition to stage 2 caseid= 56 time =  10313 transition_queue_length = 1
# Machined part placed in Stage 2 Inventory. caseid= 56 time = 10313 inv_size = 3
# Begin_stage1_machining caseid = 58 time =  10313 queue1_length = 15
# Prepared part joins queue caseid = 73 time = 10335 queue_length = 15
# Next prepared part for Stage 1:  10473
# End_stage2_machining for inventory parts caseid= 50 time =  10377 queue2_length = 3
# Begin_stage2_machining for inventory parts, caseid = 53 time =  10377 inv2_length = 3
# Prepared part joins queue caseid = 74 time = 10473 queue_length = 16
# Next prepared part for Stage 1:  10622
# End_stage1_machining caseid= 54 time =  10573 queue1_length = 16
# Transition to stage 2 caseid= 54 time =  10573 transition_queue_length = 1
# Machined part placed in Stage 2 Inventory. caseid= 54 time = 10573 inv_size = 3
# Begin_stage1_machining caseid = 59 time =  10573 queue1_length = 16
# Prepared part joins queue caseid = 75 time = 10622 queue_length = 16
# Next prepared part for Stage 1:  10764
# End_stage1_machining caseid= 57 time =  10669 queue1_length = 16
# Transition to stage 2 caseid= 57 time =  10669 transition_queue_length = 1
# Machined part placed in Stage 2 Inventory. caseid= 57 time = 10669 inv_size = 4
# Begin_stage1_machining caseid = 60 time =  10669 queue1_length = 16
# End_stage1_machining caseid= 58 time =  10751 queue1_length = 15
# Transition to stage 2 caseid= 58 time =  10751 transition_queue_length = 1
# Machined part placed in Stage 2 Inventory. caseid= 58 time = 10751 inv_size = 5
# Begin_stage1_machining caseid = 61 time =  10751 queue1_length = 15
# Prepared part joins queue caseid = 76 time = 10764 queue_length = 15
# Next prepared part for Stage 1:  10812
# End_stage2_machining for inventory parts caseid= 52 time =  10773 queue2_length = 5
# Begin_stage2_machining for inventory parts, caseid = 55 time =  10773 inv2_length = 5
# Prepared part joins queue caseid = 77 time = 10812 queue_length = 16
# Next prepared part for Stage 1:  10851
# Prepared part joins queue caseid = 78 time = 10851 queue_length = 17
# Next prepared part for Stage 1:  11020
# End_stage1_machining caseid= 59 time =  10966 queue1_length = 17
# Transition to stage 2 caseid= 59 time =  10966 transition_queue_length = 1
# Machined part placed in Stage 2 Inventory. caseid= 59 time = 10966 inv_size = 5
# Begin_stage1_machining caseid = 62 time =  10966 queue1_length = 17
# End_stage2_machining for inventory parts caseid= 53 time =  10977 queue2_length = 5
# Begin_stage2_machining for inventory parts, caseid = 56 time =  10977 inv2_length = 5
# Prepared part joins queue caseid = 79 time = 11020 queue_length = 17
# Next prepared part for Stage 1:  11094
# End_stage1_machining caseid= 61 time =  11051 queue1_length = 17
# Transition to stage 2 caseid= 61 time =  11051 transition_queue_length = 1
# Machined part placed in Stage 2 Inventory. caseid= 61 time = 11051 inv_size = 5
# Begin_stage1_machining caseid = 63 time =  11051 queue1_length = 17
# Prepared part joins queue caseid = 80 time = 11094 queue_length = 17
# Next prepared part for Stage 1:  11143
# Prepared part joins queue caseid = 81 time = 11143 queue_length = 18
# Next prepared part for Stage 1:  11208
# Prepared part joins queue caseid = 82 time = 11208 queue_length = 19
# Next prepared part for Stage 1:  11516
# End_stage1_machining caseid= 62 time =  11447 queue1_length = 19
# Transition to stage 2 caseid= 62 time =  11447 transition_queue_length = 1
# Machined part placed in Stage 2 Inventory. caseid= 62 time = 11447 inv_size = 6
# Begin_stage1_machining caseid = 64 time =  11447 queue1_length = 19
# Prepared part joins queue caseid = 83 time = 11516 queue_length = 19
# Next prepared part for Stage 1:  11562
# Prepared part joins queue caseid = 84 time = 11562 queue_length = 20
# Next prepared part for Stage 1:  12046
# End_stage1_machining caseid= 63 time =  11651 queue1_length = 20
# Transition to stage 2 caseid= 63 time =  11651 transition_queue_length = 1
# Machined part placed in Stage 2 Inventory. caseid= 63 time = 11651 inv_size = 7
# Begin_stage1_machining caseid = 65 time =  11651 queue1_length = 20
# End_stage1_machining caseid= 64 time =  11764 queue1_length = 19
# Transition to stage 2 caseid= 64 time =  11764 transition_queue_length = 1
# Machined part placed in Stage 2 Inventory. caseid= 64 time = 11764 inv_size = 8
# Begin_stage1_machining caseid = 66 time =  11764 queue1_length = 19
# End_stage1_machining caseid= 60 time =  11869 queue1_length = 18
# Transition to stage 2 caseid= 60 time =  11869 transition_queue_length = 1
# Machined part placed in Stage 2 Inventory. caseid= 60 time = 11869 inv_size = 9
# Begin_stage1_machining caseid = 67 time =  11869 queue1_length = 18
# End_stage1_machining caseid= 65 time =  11951 queue1_length = 17
# Transition to stage 2 caseid= 65 time =  11951 transition_queue_length = 1
# Machined part placed in Stage 2 Inventory. caseid= 65 time = 11951 inv_size = 10
# Begin_stage1_machining caseid = 68 time =  11951 queue1_length = 17
# Prepared part joins queue caseid = 85 time = 12046 queue_length = 17
# Next prepared part for Stage 1:  12103
# End_stage1_machining caseid= 66 time =  12064 queue1_length = 17
# Transition to stage 2 caseid= 66 time =  12064 transition_queue_length = 1
# Machined part placed in Stage 2 Inventory. caseid= 66 time = 12064 inv_size = 11
# Begin_stage1_machining caseid = 69 time =  12064 queue1_length = 17
# Prepared part joins queue caseid = 86 time = 12103 queue_length = 17
# Next prepared part for Stage 1:  12192
# End_stage1_machining caseid= 67 time =  12169 queue1_length = 17
# Transition to stage 2 caseid= 67 time =  12169 transition_queue_length = 1
# Machined part placed in Stage 2 Inventory. caseid= 67 time = 12169 inv_size = 12
# Begin_stage1_machining caseid = 70 time =  12169 queue1_length = 17
# Prepared part joins queue caseid = 87 time = 12192 queue_length = 17
# Next prepared part for Stage 1:  12224
# Prepared part joins queue caseid = 88 time = 12224 queue_length = 18
# Next prepared part for Stage 1:  12617
# End_stage1_machining caseid= 68 time =  12251 queue1_length = 18
# Transition to stage 2 caseid= 68 time =  12251 transition_queue_length = 1
# Machined part placed in Stage 2 Inventory. caseid= 68 time = 12251 inv_size = 13
# Begin_stage1_machining caseid = 71 time =  12251 queue1_length = 18
# End_stage1_machining caseid= 69 time =  12364 queue1_length = 17
# Transition to stage 2 caseid= 69 time =  12364 transition_queue_length = 1
# Machined part placed in Stage 2 Inventory. caseid= 69 time = 12364 inv_size = 14
# Begin_stage1_machining caseid = 72 time =  12364 queue1_length = 17
# End_stage1_machining caseid= 71 time =  12551 queue1_length = 16
# Transition to stage 2 caseid= 71 time =  12551 transition_queue_length = 1
# Machined part placed in Stage 2 Inventory. caseid= 71 time = 12551 inv_size = 15
# Begin_stage1_machining caseid = 73 time =  12551 queue1_length = 16
# End_stage2_machining for inventory parts caseid= 55 time =  12573 queue2_length = 15
# Begin_stage2_machining for inventory parts, caseid = 54 time =  12573 inv2_length = 15
# Prepared part joins queue caseid = 89 time = 12617 queue_length = 16
# Next prepared part for Stage 1:  12695
# Prepared part joins queue caseid = 90 time = 12695 queue_length = 17
# Next prepared part for Stage 1:  12804
# End_stage2_machining for inventory parts caseid= 56 time =  12748 queue2_length = 14
# Begin_stage2_machining for inventory parts, caseid = 57 time =  12748 inv2_length = 14
# Prepared part joins queue caseid = 91 time = 12804 queue_length = 18
# Next prepared part for Stage 1:  13091
# End_stage1_machining caseid= 73 time =  12851 queue1_length = 18
# Transition to stage 2 caseid= 73 time =  12851 transition_queue_length = 1
# Machined part placed in Stage 2 Inventory. caseid= 73 time = 12851 inv_size = 14
# Begin_stage1_machining caseid = 74 time =  12851 queue1_length = 18
# End_stage1_machining caseid= 70 time =  12987 queue1_length = 17
# Transition to stage 2 caseid= 70 time =  12987 transition_queue_length = 1
# Machined part placed in Stage 2 Inventory. caseid= 70 time = 12987 inv_size = 15
# Begin_stage1_machining caseid = 75 time =  12987 queue1_length = 17
# Prepared part joins queue caseid = 92 time = 13091 queue_length = 17
# Next prepared part for Stage 1:  13345
# End_stage2_machining for inventory parts caseid= 54 time =  13173 queue2_length = 15
# Begin_stage2_machining for inventory parts, caseid = 58 time =  13173 inv2_length = 15
# End_stage1_machining caseid= 72 time =  13188 queue1_length = 17
# Transition to stage 2 caseid= 72 time =  13188 transition_queue_length = 1
# Machined part placed in Stage 2 Inventory. caseid= 72 time = 13188 inv_size = 15
# Begin_stage1_machining caseid = 76 time =  13188 queue1_length = 17
# End_stage1_machining caseid= 75 time =  13287 queue1_length = 16
# Transition to stage 2 caseid= 75 time =  13287 transition_queue_length = 1
# Machined part placed in Stage 2 Inventory. caseid= 75 time = 13287 inv_size = 16
# Begin_stage1_machining caseid = 77 time =  13287 queue1_length = 16
# Prepared part joins queue caseid = 93 time = 13345 queue_length = 16
# Next prepared part for Stage 1:  13601
# End_stage1_machining caseid= 76 time =  13488 queue1_length = 16
# Transition to stage 2 caseid= 76 time =  13488 transition_queue_length = 1
# Machined part placed in Stage 2 Inventory. caseid= 76 time = 13488 inv_size = 17
# Begin_stage1_machining caseid = 78 time =  13488 queue1_length = 16
# End_stage1_machining caseid= 74 time =  13549 queue1_length = 15
# Transition to stage 2 caseid= 74 time =  13549 transition_queue_length = 1
# Machined part placed in Stage 2 Inventory. caseid= 74 time = 13549 inv_size = 18
# Begin_stage1_machining caseid = 79 time =  13549 queue1_length = 15
# End_stage1_machining caseid= 77 time =  13587 queue1_length = 14
# Transition to stage 2 caseid= 77 time =  13587 transition_queue_length = 1
# Machined part placed in Stage 2 Inventory. caseid= 77 time = 13587 inv_size = 19
# Begin_stage1_machining caseid = 80 time =  13587 queue1_length = 14
# Prepared part joins queue caseid = 94 time = 13601 queue_length = 14
# Next prepared part for Stage 1:  13687
# Prepared part joins queue caseid = 95 time = 13687 queue_length = 15
# Next prepared part for Stage 1:  13823
# Prepared part joins queue caseid = 96 time = 13823 queue_length = 16
# Next prepared part for Stage 1:  13826
# Prepared part joins queue caseid = 97 time = 13826 queue_length = 17
# Next prepared part for Stage 1:  13992
# End_stage1_machining caseid= 79 time =  13849 queue1_length = 17
# Transition to stage 2 caseid= 79 time =  13849 transition_queue_length = 1
# Machined part placed in Stage 2 Inventory. caseid= 79 time = 13849 inv_size = 20
# Begin_stage1_machining caseid = 81 time =  13849 queue1_length = 17
# Prepared part joins queue caseid = 98 time = 13992 queue_length = 17
# Next prepared part for Stage 1:  14079
# Prepared part joins queue caseid = 99 time = 14079 queue_length = 18
# Next prepared part for Stage 1:  14276
# End_stage1_machining caseid= 81 time =  14228 queue1_length = 18
# Transition to stage 2 caseid= 81 time =  14228 transition_queue_length = 1
# Machined part placed in Stage 2 Inventory. caseid= 81 time = 14228 inv_size = 21
# Begin_stage1_machining caseid = 82 time =  14228 queue1_length = 18
# Prepared part joins queue caseid = 100 time = 14276 queue_length = 18
# Next prepared part for Stage 1:  14713
# End_stage1_machining caseid= 82 time =  14528 queue1_length = 18
# Transition to stage 2 caseid= 82 time =  14528 transition_queue_length = 1
# Machined part placed in Stage 2 Inventory. caseid= 82 time = 14528 inv_size = 22
# Begin_stage1_machining caseid = 83 time =  14528 queue1_length = 18
# End_stage2_machining for inventory parts caseid= 57 time =  14548 queue2_length = 22
# Begin_stage2_machining for inventory parts, caseid = 59 time =  14548 inv2_length = 22
# End_stage1_machining caseid= 78 time =  14658 queue1_length = 17
# Transition to stage 2 caseid= 78 time =  14658 transition_queue_length = 1
# Machined part placed in Stage 2 Inventory. caseid= 78 time = 14658 inv_size = 22
# Begin_stage1_machining caseid = 84 time =  14658 queue1_length = 17
# Prepared part joins queue caseid = 101 time = 14713 queue_length = 17
# Next prepared part for Stage 1:  15067
# End_stage1_machining caseid= 80 time =  14787 queue1_length = 17
# Transition to stage 2 caseid= 80 time =  14787 transition_queue_length = 1
# Machined part placed in Stage 2 Inventory. caseid= 80 time = 14787 inv_size = 23
# Begin_stage1_machining caseid = 85 time =  14787 queue1_length = 17
# End_stage1_machining caseid= 83 time =  14828 queue1_length = 16
# Transition to stage 2 caseid= 83 time =  14828 transition_queue_length = 1
# Machined part placed in Stage 2 Inventory. caseid= 83 time = 14828 inv_size = 24
# Begin_stage1_machining caseid = 86 time =  14828 queue1_length = 16
# End_stage1_machining caseid= 84 time =  14958 queue1_length = 15
# Transition to stage 2 caseid= 84 time =  14958 transition_queue_length = 1
# Machined part placed in Stage 2 Inventory. caseid= 84 time = 14958 inv_size = 25
# Begin_stage1_machining caseid = 87 time =  14958 queue1_length = 15
# End_stage2_machining for inventory parts caseid= 58 time =  14973 queue2_length = 25
# Begin_stage2_machining for inventory parts, caseid = 61 time =  14973 inv2_length = 25
# Prepared part joins queue caseid = 102 time = 15067 queue_length = 15
# Next prepared part for Stage 1:  15236
# End_stage1_machining caseid= 85 time =  15087 queue1_length = 15
# Transition to stage 2 caseid= 85 time =  15087 transition_queue_length = 1
# Machined part placed in Stage 2 Inventory. caseid= 85 time = 15087 inv_size = 25
# Begin_stage1_machining caseid = 88 time =  15087 queue1_length = 15
# End_stage2_machining for inventory parts caseid= 59 time =  15148 queue2_length = 25
# Begin_stage2_machining for inventory parts, caseid = 62 time =  15148 inv2_length = 25
# Prepared part joins queue caseid = 103 time = 15236 queue_length = 15
# Next prepared part for Stage 1:  15579
# End_stage1_machining caseid= 88 time =  15387 queue1_length = 15
# Transition to stage 2 caseid= 88 time =  15387 transition_queue_length = 1
# Machined part placed in Stage 2 Inventory. caseid= 88 time = 15387 inv_size = 25
# Begin_stage1_machining caseid = 89 time =  15387 queue1_length = 15
# End_stage1_machining caseid= 87 time =  15547 queue1_length = 14
# Transition to stage 2 caseid= 87 time =  15547 transition_queue_length = 1
# Machined part placed in Stage 2 Inventory. caseid= 87 time = 15547 inv_size = 26
# Begin_stage1_machining caseid = 90 time =  15547 queue1_length = 14
# Prepared part joins queue caseid = 104 time = 15579 queue_length = 14
# Next prepared part for Stage 1:  15600
# Prepared part joins queue caseid = 105 time = 15600 queue_length = 15
# Next prepared part for Stage 1:  15695
# Prepared part joins queue caseid = 106 time = 15695 queue_length = 16
# Next prepared part for Stage 1:  15723
# Prepared part joins queue caseid = 107 time = 15723 queue_length = 17
# Next prepared part for Stage 1:  16129
# End_stage1_machining caseid= 86 time =  16028 queue1_length = 17
# Transition to stage 2 caseid= 86 time =  16028 transition_queue_length = 1
# Machined part placed in Stage 2 Inventory. caseid= 86 time = 16028 inv_size = 27
# Begin_stage1_machining caseid = 91 time =  16028 queue1_length = 17
# Prepared part joins queue caseid = 108 time = 16129 queue_length = 17
# Next prepared part for Stage 1:  16853
# End_stage1_machining caseid= 89 time =  16319 queue1_length = 17
# Transition to stage 2 caseid= 89 time =  16319 transition_queue_length = 1
# Machined part placed in Stage 2 Inventory. caseid= 89 time = 16319 inv_size = 28
# Begin_stage1_machining caseid = 92 time =  16319 queue1_length = 17
# End_stage1_machining caseid= 91 time =  16328 queue1_length = 16
# Transition to stage 2 caseid= 91 time =  16328 transition_queue_length = 1
# Machined part placed in Stage 2 Inventory. caseid= 91 time = 16328 inv_size = 29
# Begin_stage1_machining caseid = 93 time =  16328 queue1_length = 16
# End_stage2_machining for inventory parts caseid= 62 time =  16489 queue2_length = 29
# Begin_stage2_machining for inventory parts, caseid = 63 time =  16489 inv2_length = 29
# End_stage1_machining caseid= 92 time =  16619 queue1_length = 15
# Transition to stage 2 caseid= 92 time =  16619 transition_queue_length = 1
# Machined part placed in Stage 2 Inventory. caseid= 92 time = 16619 inv_size = 29
# Begin_stage1_machining caseid = 94 time =  16619 queue1_length = 15
# End_stage1_machining caseid= 90 time =  16747 queue1_length = 14
# Transition to stage 2 caseid= 90 time =  16747 transition_queue_length = 1
# Machined part placed in Stage 2 Inventory. caseid= 90 time = 16747 inv_size = 30
# Begin_stage1_machining caseid = 95 time =  16747 queue1_length = 14
# End_stage2_machining for inventory parts caseid= 61 time =  16773 queue2_length = 30
# Begin_stage2_machining for inventory parts, caseid = 64 time =  16773 inv2_length = 30
# Prepared part joins queue caseid = 109 time = 16853 queue_length = 14
# Next prepared part for Stage 1:  17066
# End_stage1_machining caseid= 93 time =  17030 queue1_length = 14
# Transition to stage 2 caseid= 93 time =  17030 transition_queue_length = 1
# Machined part placed in Stage 2 Inventory. caseid= 93 time = 17030 inv_size = 30
# Begin_stage1_machining caseid = 96 time =  17030 queue1_length = 14
# Prepared part joins queue caseid = 110 time = 17066 queue_length = 14
# Next prepared part for Stage 1:  17129
# End_stage2_machining for inventory parts caseid= 63 time =  17089 queue2_length = 30
# Begin_stage2_machining for inventory parts, caseid = 60 time =  17089 inv2_length = 30
# End_stage1_machining caseid= 95 time =  17119 queue1_length = 14
# Transition to stage 2 caseid= 95 time =  17119 transition_queue_length = 1
# Machined part placed in Stage 2 Inventory. caseid= 95 time = 17119 inv_size = 30
# Begin_stage1_machining caseid = 97 time =  17119 queue1_length = 14
# Prepared part joins queue caseid = 111 time = 17129 queue_length = 14
# Next prepared part for Stage 1:  17385
# End_stage1_machining caseid= 94 time =  17288 queue1_length = 14
# Transition to stage 2 caseid= 94 time =  17288 transition_queue_length = 1
# Machined part placed in Stage 2 Inventory. caseid= 94 time = 17288 inv_size = 31
# Begin_stage1_machining caseid = 98 time =  17288 queue1_length = 14
# End_stage2_machining for inventory parts caseid= 64 time =  17373 queue2_length = 31
# Begin_stage2_machining for inventory parts, caseid = 65 time =  17373 inv2_length = 31
# Prepared part joins queue caseid = 112 time = 17385 queue_length = 14
# Next prepared part for Stage 1:  17426
# Prepared part joins queue caseid = 113 time = 17426 queue_length = 15
# Next prepared part for Stage 1:  17585
# Prepared part joins queue caseid = 114 time = 17585 queue_length = 16
# Next prepared part for Stage 1:  17754
# End_stage1_machining caseid= 97 time =  17654 queue1_length = 16
# Transition to stage 2 caseid= 97 time =  17654 transition_queue_length = 1
# Machined part placed in Stage 2 Inventory. caseid= 97 time = 17654 inv_size = 31
# Begin_stage1_machining caseid = 99 time =  17654 queue1_length = 16
# End_stage1_machining caseid= 98 time =  17675 queue1_length = 15
# Transition to stage 2 caseid= 98 time =  17675 transition_queue_length = 1
# Machined part placed in Stage 2 Inventory. caseid= 98 time = 17675 inv_size = 32
# Begin_stage1_machining caseid = 100 time =  17675 queue1_length = 15
# End_stage2_machining for inventory parts caseid= 60 time =  17689 queue2_length = 32
# Begin_stage2_machining for inventory parts, caseid = 66 time =  17689 inv2_length = 32
# Prepared part joins queue caseid = 115 time = 17754 queue_length = 15
# Next prepared part for Stage 1:  17911
# End_stage1_machining caseid= 96 time =  17835 queue1_length = 15
# Transition to stage 2 caseid= 96 time =  17835 transition_queue_length = 1
# Machined part placed in Stage 2 Inventory. caseid= 96 time = 17835 inv_size = 32
# Begin_stage1_machining caseid = 101 time =  17835 queue1_length = 15
# Prepared part joins queue caseid = 116 time = 17911 queue_length = 15
# Next prepared part for Stage 1:  18027
# End_stage2_machining for inventory parts caseid= 65 time =  17973 queue2_length = 32
# Begin_stage2_machining for inventory parts, caseid = 67 time =  17973 inv2_length = 32
# End_stage1_machining caseid= 99 time =  18014 queue1_length = 15
# Transition to stage 2 caseid= 99 time =  18014 transition_queue_length = 1
# Machined part placed in Stage 2 Inventory. caseid= 99 time = 18014 inv_size = 32
# Begin_stage1_machining caseid = 102 time =  18014 queue1_length = 15
# Prepared part joins queue caseid = 117 time = 18027 queue_length = 15
# Next prepared part for Stage 1:  18153
# End_stage1_machining caseid= 101 time =  18135 queue1_length = 15
# Transition to stage 2 caseid= 101 time =  18135 transition_queue_length = 1
# Machined part placed in Stage 2 Inventory. caseid= 101 time = 18135 inv_size = 33
# Begin_stage1_machining caseid = 103 time =  18135 queue1_length = 15
# Prepared part joins queue caseid = 118 time = 18153 queue_length = 15
# Next prepared part for Stage 1:  18220
# Prepared part joins queue caseid = 119 time = 18220 queue_length = 16
# Next prepared part for Stage 1:  18483
# End_stage1_machining caseid= 100 time =  18245 queue1_length = 16
# Transition to stage 2 caseid= 100 time =  18245 transition_queue_length = 1
# Machined part placed in Stage 2 Inventory. caseid= 100 time = 18245 inv_size = 34
# Begin_stage1_machining caseid = 104 time =  18245 queue1_length = 16
# End_stage2_machining for inventory parts caseid= 66 time =  18289 queue2_length = 34
# Begin_stage2_machining for inventory parts, caseid = 68 time =  18289 inv2_length = 34
# End_stage1_machining caseid= 102 time =  18314 queue1_length = 15
# Transition to stage 2 caseid= 102 time =  18314 transition_queue_length = 1
# Machined part placed in Stage 2 Inventory. caseid= 102 time = 18314 inv_size = 34
# Begin_stage1_machining caseid = 105 time =  18314 queue1_length = 15
# End_stage1_machining caseid= 103 time =  18435 queue1_length = 14
# Transition to stage 2 caseid= 103 time =  18435 transition_queue_length = 1
# Machined part placed in Stage 2 Inventory. caseid= 103 time = 18435 inv_size = 35
# Begin_stage1_machining caseid = 106 time =  18435 queue1_length = 14
# Prepared part joins queue caseid = 120 time = 18483 queue_length = 14
# Next prepared part for Stage 1:  18659
# End_stage2_machining for inventory parts caseid= 67 time =  18573 queue2_length = 35
# Begin_stage2_machining for inventory parts, caseid = 69 time =  18573 inv2_length = 35
# Prepared part joins queue caseid = 121 time = 18659 queue_length = 15
# Next prepared part for Stage 1:  18741
# End_stage1_machining caseid= 104 time =  18721 queue1_length = 15
# Transition to stage 2 caseid= 104 time =  18721 transition_queue_length = 1
# Machined part placed in Stage 2 Inventory. caseid= 104 time = 18721 inv_size = 35
# Begin_stage1_machining caseid = 107 time =  18721 queue1_length = 15
# ...
# Next prepared part for Stage 1:  42022
# Prepared part placed in Stage 1 Inventory. caseid= 262 time = 42022 inv_size = 78
# Next prepared part for Stage 1:  42086
# Prepared part placed in Stage 1 Inventory. caseid= 263 time = 42086 inv_size = 79
# Next prepared part for Stage 1:  42094
# Prepared part placed in Stage 1 Inventory. caseid= 264 time = 42094 inv_size = 80
# Next prepared part for Stage 1:  42119
# Prepared part placed in Stage 1 Inventory. caseid= 265 time = 42119 inv_size = 81
# Next prepared part for Stage 1:  42512
# End_stage2_machining for inventory parts caseid= 110 time =  42397 queue2_length = 53
# Begin_stage2_machining for inventory parts, caseid = 111 time =  42397 inv2_length = 53
# Prepared part placed in Stage 1 Inventory. caseid= 266 time = 42512 inv_size = 82
# Next prepared part for Stage 1:  42565
# Prepared part placed in Stage 1 Inventory. caseid= 267 time = 42565 inv_size = 83
# Next prepared part for Stage 1:  42718
# Prepared part placed in Stage 1 Inventory. caseid= 268 time = 42718 inv_size = 84
# Next prepared part for Stage 1:  43013
# Prepared part placed in Stage 1 Inventory. caseid= 269 time = 43013 inv_size = 85
# Next prepared part for Stage 1:  43060
# Prepared part placed in Stage 1 Inventory. caseid= 270 time = 43060 inv_size = 86
# Next prepared part for Stage 1:  43069
# Prepared part placed in Stage 1 Inventory. caseid= 271 time = 43069 inv_size = 87
# Next prepared part for Stage 1:  43409
# End_stage2_machining for inventory parts caseid= 111 time =  43262 queue2_length = 52
# Begin_stage2_machining for inventory parts, caseid = 114 time =  43262 inv2_length = 52
# Prepared part placed in Stage 1 Inventory. caseid= 272 time = 43409 inv_size = 88
# Next prepared part for Stage 1:  43497
# Prepared part placed in Stage 1 Inventory. caseid= 273 time = 43497 inv_size = 89
# Next prepared part for Stage 1:  44051
# End_stage2_machining for inventory parts caseid= 113 time =  43505 queue2_length = 51
# Begin_stage2_machining for inventory parts, caseid = 112 time =  43505 inv2_length = 51
# End_stage2_machining for inventory parts caseid= 114 time =  43862 queue2_length = 50
# Begin_stage2_machining for inventory parts, caseid = 116 time =  43862 inv2_length = 50
# Prepared part placed in Stage 1 Inventory. caseid= 274 time = 44051 inv_size = 90
# Next prepared part for Stage 1:  44074
# Prepared part placed in Stage 1 Inventory. caseid= 275 time = 44074 inv_size = 91
# Next prepared part for Stage 1:  44741
# End_stage2_machining for inventory parts caseid= 112 time =  44300 queue2_length = 49
# Begin_stage2_machining for inventory parts, caseid = 115 time =  44300 inv2_length = 49
# Prepared part placed in Stage 1 Inventory. caseid= 276 time = 44741 inv_size = 92
# Next prepared part for Stage 1:  45135
# End_stage2_machining for inventory parts caseid= 115 time =  45029 queue2_length = 48
# Begin_stage2_machining for inventory parts, caseid = 117 time =  45029 inv2_length = 48
# End_stage2_machining for inventory parts caseid= 116 time =  45079 queue2_length = 47
# Begin_stage2_machining for inventory parts, caseid = 140 time =  45079 inv2_length = 47
# Prepared part placed in Stage 1 Inventory. caseid= 277 time = 45135 inv_size = 93
# Next prepared part for Stage 1:  45668
# Prepared part placed in Stage 1 Inventory. caseid= 278 time = 45668 inv_size = 94
# Next prepared part for Stage 1:  45770
# End_stage2_machining for inventory parts caseid= 140 time =  45679 queue2_length = 46
# Begin_stage2_machining for inventory parts, caseid = 118 time =  45679 inv2_length = 46
# Prepared part placed in Stage 1 Inventory. caseid= 279 time = 45770 inv_size = 95
# Next prepared part for Stage 1:  45814
# Prepared part placed in Stage 1 Inventory. caseid= 280 time = 45814 inv_size = 96
# Next prepared part for Stage 1:  45959
# Prepared part placed in Stage 1 Inventory. caseid= 281 time = 45959 inv_size = 97
# Next prepared part for Stage 1:  46107
# Prepared part placed in Stage 1 Inventory. caseid= 282 time = 46107 inv_size = 98
# Next prepared part for Stage 1:  46630
# End_stage2_machining for inventory parts caseid= 118 time =  46279 queue2_length = 45
# Begin_stage2_machining for inventory parts, caseid = 139 time =  46279 inv2_length = 45
# Prepared part placed in Stage 1 Inventory. caseid= 283 time = 46630 inv_size = 99
# Next prepared part for Stage 1:  46794
# Prepared part placed in Stage 1 Inventory. caseid= 284 time = 46794 inv_size = 100
# Next prepared part for Stage 1:  47149
# End_stage2_machining for inventory parts caseid= 117 time =  46829 queue2_length = 44
# Begin_stage2_machining for inventory parts, caseid = 119 time =  46829 inv2_length = 44
# Prepared part placed in Stage 1 Inventory. caseid= 285 time = 47149 inv_size = 101
# Next prepared part for Stage 1:  47326
# End_stage2_machining for inventory parts caseid= 139 time =  47188 queue2_length = 43
# Begin_stage2_machining for inventory parts, caseid = 120 time =  47188 inv2_length = 43
# Prepared part placed in Stage 1 Inventory. caseid= 286 time = 47326 inv_size = 102
# Next prepared part for Stage 1:  47420
# Prepared part placed in Stage 1 Inventory. caseid= 287 time = 47420 inv_size = 103
# Next prepared part for Stage 1:  47560
# Prepared part placed in Stage 1 Inventory. caseid= 288 time = 47560 inv_size = 104
# Next prepared part for Stage 1:  48010
# End_stage2_machining for inventory parts caseid= 120 time =  47788 queue2_length = 42
# Begin_stage2_machining for inventory parts, caseid = 121 time =  47788 inv2_length = 42
# Prepared part placed in Stage 1 Inventory. caseid= 289 time = 48010 inv_size = 105
# Next prepared part for Stage 1:  48110
# Prepared part placed in Stage 1 Inventory. caseid= 290 time = 48110 inv_size = 106
# Next prepared part for Stage 1:  48453
# Prepared part placed in Stage 1 Inventory. caseid= 291 time = 48453 inv_size = 107
# Next prepared part for Stage 1:  48785
# End_stage2_machining for inventory parts caseid= 119 time =  48629 queue2_length = 41
# Begin_stage2_machining for inventory parts, caseid = 122 time =  48629 inv2_length = 41
# Prepared part placed in Stage 1 Inventory. caseid= 292 time = 48785 inv_size = 108
# Next prepared part for Stage 1:  49150
# Prepared part placed in Stage 1 Inventory. caseid= 293 time = 49150 inv_size = 109
# Next prepared part for Stage 1:  49369
# End_stage2_machining for inventory parts caseid= 122 time =  49229 queue2_length = 40
# Begin_stage2_machining for inventory parts, caseid = 123 time =  49229 inv2_length = 40
# Prepared part placed in Stage 1 Inventory. caseid= 294 time = 49369 inv_size = 110
# Next prepared part for Stage 1:  49393
# Prepared part placed in Stage 1 Inventory. caseid= 295 time = 49393 inv_size = 111
# Next prepared part for Stage 1:  49619
# End_stage2_machining for inventory parts caseid= 121 time =  49425 queue2_length = 39
# Begin_stage2_machining for inventory parts, caseid = 125 time =  49425 inv2_length = 39
# Prepared part placed in Stage 1 Inventory. caseid= 296 time = 49619 inv_size = 112
# Next prepared part for Stage 1:  49675
# Prepared part placed in Stage 1 Inventory. caseid= 297 time = 49675 inv_size = 113
# Next prepared part for Stage 1:  49831
# Prepared part placed in Stage 1 Inventory. caseid= 298 time = 49831 inv_size = 114
# Next prepared part for Stage 1:  49867
# Prepared part placed in Stage 1 Inventory. caseid= 299 time = 49867 inv_size = 115
# Next prepared part for Stage 1:  49903
# Prepared part placed in Stage 1 Inventory. caseid= 300 time = 49903 inv_size = 116
# Next prepared part for Stage 1:  50279
# End_stage2_machining for inventory parts caseid= 125 time =  50233 queue2_length = 38
# Begin_stage2_machining for inventory parts, caseid = 124 time =  50233 inv2_length = 38
# Prepared part placed in Stage 1 Inventory. caseid= 301 time = 50279 inv_size = 117
# Next prepared part for Stage 1:  50324
# Prepared part placed in Stage 1 Inventory. caseid= 302 time = 50324 inv_size = 118
# Next prepared part for Stage 1:  50351
# Prepared part placed in Stage 1 Inventory. caseid= 303 time = 50351 inv_size = 119
# Next prepared part for Stage 1:  50453
# Prepared part placed in Stage 1 Inventory. caseid= 304 time = 50453 inv_size = 120
# Next prepared part for Stage 1:  50506
# Prepared part placed in Stage 1 Inventory. caseid= 305 time = 50506 inv_size = 121
# Next prepared part for Stage 1:  50634
# Prepared part placed in Stage 1 Inventory. caseid= 306 time = 50634 inv_size = 122
# Next prepared part for Stage 1:  50642
# Prepared part placed in Stage 1 Inventory. caseid= 307 time = 50642 inv_size = 123
# Next prepared part for Stage 1:  50660
# Prepared part placed in Stage 1 Inventory. caseid= 308 time = 50660 inv_size = 124
# Next prepared part for Stage 1:  50772
# Prepared part placed in Stage 1 Inventory. caseid= 309 time = 50772 inv_size = 125
# Next prepared part for Stage 1:  50846
# Prepared part placed in Stage 1 Inventory. caseid= 310 time = 50846 inv_size = 126
# Next prepared part for Stage 1:  50856
# Prepared part placed in Stage 1 Inventory. caseid= 311 time = 50856 inv_size = 127
# Next prepared part for Stage 1:  51473
# End_stage2_machining for inventory parts caseid= 123 time =  51029 queue2_length = 37
# Begin_stage2_machining for inventory parts, caseid = 128 time =  51029 inv2_length = 37
# Prepared part placed in Stage 1 Inventory. caseid= 312 time = 51473 inv_size = 128
# Next prepared part for Stage 1:  51605
# Prepared part placed in Stage 1 Inventory. caseid= 313 time = 51605 inv_size = 129
# Next prepared part for Stage 1:  51853
# End_stage2_machining for inventory parts caseid= 124 time =  51801 queue2_length = 36
# Begin_stage2_machining for inventory parts, caseid = 126 time =  51801 inv2_length = 36
# Prepared part placed in Stage 1 Inventory. caseid= 314 time = 51853 inv_size = 130
# Next prepared part for Stage 1:  52202
# Prepared part placed in Stage 1 Inventory. caseid= 315 time = 52202 inv_size = 131
# Next prepared part for Stage 1:  52218
# Prepared part placed in Stage 1 Inventory. caseid= 316 time = 52218 inv_size = 132
# Next prepared part for Stage 1:  52699
# End_stage2_machining for inventory parts caseid= 126 time =  52401 queue2_length = 35
# Begin_stage2_machining for inventory parts, caseid = 129 time =  52401 inv2_length = 35
# Prepared part placed in Stage 1 Inventory. caseid= 317 time = 52699 inv_size = 133
# Next prepared part for Stage 1:  52804
# Prepared part placed in Stage 1 Inventory. caseid= 318 time = 52804 inv_size = 134
# Next prepared part for Stage 1:  52951
# End_stage2_machining for inventory parts caseid= 128 time =  52829 queue2_length = 34
# Begin_stage2_machining for inventory parts, caseid = 130 time =  52829 inv2_length = 34
# Prepared part placed in Stage 1 Inventory. caseid= 319 time = 52951 inv_size = 135
# Next prepared part for Stage 1:  53039
# End_stage2_machining for inventory parts caseid= 129 time =  53001 queue2_length = 33
# Begin_stage2_machining for inventory parts, caseid = 127 time =  53001 inv2_length = 33
# Prepared part placed in Stage 1 Inventory. caseid= 320 time = 53039 inv_size = 136
# Next prepared part for Stage 1:  53078
# Prepared part placed in Stage 1 Inventory. caseid= 321 time = 53078 inv_size = 137
# Next prepared part for Stage 1:  53243
# Prepared part placed in Stage 1 Inventory. caseid= 322 time = 53243 inv_size = 138
# Next prepared part for Stage 1:  53350
# Prepared part placed in Stage 1 Inventory. caseid= 323 time = 53350 inv_size = 139
# Next prepared part for Stage 1:  53618
# Prepared part placed in Stage 1 Inventory. caseid= 324 time = 53618 inv_size = 140
# Next prepared part for Stage 1:  53641
# Prepared part placed in Stage 1 Inventory. caseid= 325 time = 53641 inv_size = 141
# Next prepared part for Stage 1:  53830
# Prepared part placed in Stage 1 Inventory. caseid= 326 time = 53830 inv_size = 142
# Next prepared part for Stage 1:  53871
# Prepared part placed in Stage 1 Inventory. caseid= 327 time = 53871 inv_size = 143
# Next prepared part for Stage 1:  54120
# End_stage2_machining for inventory parts caseid= 127 time =  53887 queue2_length = 32
# Begin_stage2_machining for inventory parts, caseid = 154 time =  53887 inv2_length = 32
# Prepared part placed in Stage 1 Inventory. caseid= 328 time = 54120 inv_size = 144
# Next prepared part for Stage 1:  54301
# Prepared part placed in Stage 1 Inventory. caseid= 329 time = 54301 inv_size = 145
# Next prepared part for Stage 1:  54352
# Prepared part placed in Stage 1 Inventory. caseid= 330 time = 54352 inv_size = 146
# Next prepared part for Stage 1:  54520
# End_stage2_machining for inventory parts caseid= 130 time =  54396 queue2_length = 31
# Begin_stage2_machining for inventory parts, caseid = 153 time =  54396 inv2_length = 31
# End_stage2_machining for inventory parts caseid= 154 time =  54487 queue2_length = 30
# Begin_stage2_machining for inventory parts, caseid = 155 time =  54487 inv2_length = 30
# Prepared part placed in Stage 1 Inventory. caseid= 331 time = 54520 inv_size = 147
# Next prepared part for Stage 1:  54574
# Prepared part placed in Stage 1 Inventory. caseid= 332 time = 54574 inv_size = 148
# Next prepared part for Stage 1:  54673
# Prepared part placed in Stage 1 Inventory. caseid= 333 time = 54673 inv_size = 149
# Next prepared part for Stage 1:  54908
# Prepared part placed in Stage 1 Inventory. caseid= 334 time = 54908 inv_size = 150
# Next prepared part for Stage 1:  55269
# End_stage2_machining for inventory parts caseid= 153 time =  55088 queue2_length = 29
# Begin_stage2_machining for inventory parts, caseid = 158 time =  55088 inv2_length = 29
# Prepared part placed in Stage 1 Inventory. caseid= 335 time = 55269 inv_size = 151
# Next prepared part for Stage 1:  55413
# Prepared part placed in Stage 1 Inventory. caseid= 336 time = 55413 inv_size = 152
# Next prepared part for Stage 1:  55558
# Prepared part placed in Stage 1 Inventory. caseid= 337 time = 55558 inv_size = 153
# Next prepared part for Stage 1:  55559
# Prepared part placed in Stage 1 Inventory. caseid= 338 time = 55559 inv_size = 154
# Next prepared part for Stage 1:  55593
# Prepared part placed in Stage 1 Inventory. caseid= 339 time = 55593 inv_size = 155
# Next prepared part for Stage 1:  55819
# End_stage2_machining for inventory parts caseid= 158 time =  55688 queue2_length = 28
# Begin_stage2_machining for inventory parts, caseid = 157 time =  55688 inv2_length = 28
# End_stage2_machining for inventory parts caseid= 155 time =  55771 queue2_length = 27
# Begin_stage2_machining for inventory parts, caseid = 156 time =  55771 inv2_length = 27
# Prepared part placed in Stage 1 Inventory. caseid= 340 time = 55819 inv_size = 156
# Next prepared part for Stage 1:  55991
# Prepared part placed in Stage 1 Inventory. caseid= 341 time = 55991 inv_size = 157
# Next prepared part for Stage 1:  56003
# Prepared part placed in Stage 1 Inventory. caseid= 342 time = 56003 inv_size = 158
# Next prepared part for Stage 1:  56320
# Prepared part placed in Stage 1 Inventory. caseid= 343 time = 56320 inv_size = 159
# Next prepared part for Stage 1:  56449
# End_stage2_machining for inventory parts caseid= 156 time =  56371 queue2_length = 26
# Begin_stage2_machining for inventory parts, caseid = 159 time =  56371 inv2_length = 26
# Prepared part placed in Stage 1 Inventory. caseid= 344 time = 56449 inv_size = 160
# Next prepared part for Stage 1:  56689
# Prepared part placed in Stage 1 Inventory. caseid= 345 time = 56689 inv_size = 161
# Next prepared part for Stage 1:  57020
# Prepared part placed in Stage 1 Inventory. caseid= 346 time = 57020 inv_size = 162
# Next prepared part for Stage 1:  57224
# Prepared part placed in Stage 1 Inventory. caseid= 347 time = 57224 inv_size = 163
# Next prepared part for Stage 1:  57287
# Prepared part placed in Stage 1 Inventory. caseid= 348 time = 57287 inv_size = 164
# Next prepared part for Stage 1:  57325
# Prepared part placed in Stage 1 Inventory. caseid= 349 time = 57325 inv_size = 165
# Next prepared part for Stage 1:  57554
# End_stage2_machining for inventory parts caseid= 157 time =  57488 queue2_length = 25
# Begin_stage2_machining for inventory parts, caseid = 160 time =  57488 inv2_length = 25
# Prepared part placed in Stage 1 Inventory. caseid= 350 time = 57554 inv_size = 166
# Next prepared part for Stage 1:  57656

# %%
simulation_trace_file_name = 'simulation-program-trace-' + simulation_file_identifier + '.txt'
with open(simulation_trace_file_name, 'wt') as ftrace:
    for d in data:
        print(str(d), file = ftrace)
print()        
print('simulation program trace written to file:',simulation_trace_file_name)

# convert list of tuples to list of lists
event_log_list = [list(element) for element in event_log]

# convert to pandas data frame
caseid_list = []
time_list = []
activity_list = []
for d in event_log_list:
    if d[0] > 0:
        caseid_list.append(d[0])
        time_list.append(d[1])
        activity_list.append(d[2])
event_log_df = pd.DataFrame({'caseid':caseid_list,
                             'time':time_list,
                             'activity':activity_list})
print()
print('event log stored as Pandas data frame: event_log_df')

# save event log to comma-delimited text file
event_log_file_name = 'simulation-event-log-' + simulation_file_identifier + '.csv'
event_log_df.to_csv(event_log_file_name, index = False)  
print()
print('event log written to file:',event_log_file_name)
# Out:
# simulation program trace written to file: simulation-program-trace-1-days-3-5-10-20-3-20-2-10-20-30-30.txt
#
# event log stored as Pandas data frame: event_log_df
#
# event log written to file: simulation-event-log-1-days-3-5-10-20-3-20-2-10-20-30-30.csv

# %%
print(caseid_transition.qsize())
# Out:
# 0

# %%
print()
print('Simulation parameter settings:')
print(machine1, 'Stage 1 machines')
print('  Stage 1 machine time settings (in minutes)')
print('    minimum:', min_machine1_time)
print('    mean:   ', mean_machine1_time)
print('    maximum:', max_machine1_time)
print(machine2, 'Stage 2 machines')
print('  Stage 2 machine time settings (in minutes)')
print('    minimum:', min_machine2_time)
print('    mean:   ', mean_machine2_time)
print('    maximum:', max_machine2_time)
print('mean observed during stages of machining times may deviate from the parameter setting')
print('due to censoring associated with the minimum and maximum')
print()
print('Parts set to be prepped over', mean_prep_time, 'minute(s) on average')
print('Parts will be stored in stage 1 inventory if there are', inventory1_queue_length, 'parts in the stage 1 queue')
print('Parts will be stored in stage 2 inventory if there are', inventory2_queue_length, 'parts in the stage 2 queue')
print('The simulation assumes the machine shop runs with two 8 hour shifts (16 hours of coverage per day)')
print('The simulation is set to run for ', simulation_days, ' days (',16*simulation_days,' hours /',16*60*simulation_days,' minutes)', sep ='')
print()
end_time = np.max(event_log_df["time"])
print('Results after ', end_time, ' seconds (', round(end_time/60, 2), ' minutes, ',round(end_time/(60*60),2),' hours):', sep = '')
caseid_list = pd.unique(event_log_df['caseid'])
print(len(caseid_list), 'unique parts prepped for stage 1')
print(len(event_log_df['activity'][event_log_df['activity']=='join_queue1']), 'prepped parts joined stage 1 queue')
print(len(event_log_df['activity'][event_log_df['activity']=='inv1']), 'prepped parts stored in stage 1 inventory')
print(len(event_log_df['activity'][event_log_df['activity']=='begin_stage1_machine']), 'prepped parts that began stage 1 machining process')
print(len(event_log_df['activity'][event_log_df['activity']=='end_stage1_machine']), 'prepped parts that finished stage 1 machining process')
print(caseid_queue1.qsize(), 'parts still in stage 1 queue')
print(caseid_inv1.qsize(), 'parts in stage 1 inventory')
print(len(event_log_df['activity'][event_log_df['activity']=='begin_stage2_machine']), 'machined parts that began stage 2 machining process')
print(len(event_log_df['activity'][event_log_df['activity']=='end_stage2_machine']), 'machined parts that finished stage 2 machining process')
print(caseid_queue2.qsize(), 'parts still in stage 2 queue')
print(caseid_inv2.qsize(), 'parts in stage 2 inventory')
# Out:
# Simulation parameter settings:
# 3 Stage 1 machines
#   Stage 1 machine time settings (in minutes)
#     minimum: 5
#     mean:    10
#     maximum: 20
# 2 Stage 2 machines
#   Stage 2 machine time settings (in minutes)
#     minimum: 10
#     mean:    20
#     maximum: 30
# mean observed during stages of machining times may deviate from the parameter setting
# due to censoring associated with the minimum and maximum
#
# Parts set to be prepped over 3 minute(s) on average
# Parts will be stored in stage 1 inventory if there are 20 parts in the stage 1 queue
# Parts will be stored in stage 2 inventory if there are 30 parts in the stage 2 queue
# The simulation assumes the machine shop runs with two 8 hour shifts (16 hours of coverage per day)
# The simulation is set to run for 1 days (16 hours /960 minutes)
#
# Results after 57554 seconds (959.23 minutes, 15.99 hours):
# 350 unique parts prepped for stage 1
# 164 prepped parts joined stage 1 queue
# 186 prepped parts stored in stage 1 inventory
# 164 prepped parts that began stage 1 machining process
# 164 prepped parts that finished stage 1 machining process
# 20 parts still in stage 1 queue
# 166 parts in stage 1 inventory
# 110 machined parts that began stage 2 machining process
# 108 machined parts that finished stage 2 machining process
# 30 parts still in stage 2 queue
# 24 parts in stage 2 inventory

# %%
print()
print('Simulation parameter settings:')
print(machine1, 'Stage 1 machines')
print('  Stage 1 machine time settings (in minutes)')
print('    minimum:', min_machine1_time)
print('    mean:   ', mean_machine1_time)
print('    maximum:', max_machine1_time)
print('mean observed stage 1 machine times may deviate from the parameter setting')
print('due to censoring associated with the minimum and maximum')
print()
print('Parts set to be prepped over', mean_prep_time, 'minute(s) on average')
print('Parts will be stored in stage 1 inventory if there are', inventory1_queue_length, 'parts in the stage 1 queue')
print('The simulation assumes the machine shop runs with two 8 hour shifts (16 hours of coverage per day)')
print('The simulation is set to run for ', simulation_days, ' days (',16*simulation_days,' hours /',16*60*simulation_days,' minutes)', sep ='')
print()
end_time = np.max(event_log_df["time"])
print('Results after ', end_time, ' seconds (', round(end_time/60, 2), ' minutes, ',round(end_time/(60*60),2),' hours):', sep = '')
caseid_list = pd.unique(event_log_df['caseid'])
print(len(caseid_list), 'unique parts prepped for stage 1')
print(len(event_log_df['activity'][event_log_df['activity']=='join_queue1']), 'prepped parts joined stage 1 queue')
print(len(event_log_df['activity'][event_log_df['activity']=='inv1']), 'prepped parts stored in stage 1 inventory')
print(len(event_log_df['activity'][event_log_df['activity']=='begin_stage1_machine']), 'prepped parts that began stage 1 machining process')
print(len(event_log_df['activity'][event_log_df['activity']=='end_stage1_machine']), 'prepped parts that finished stage 1 machining process')
print(caseid_queue1.qsize(), 'parts still in stage 1 queue')
print(caseid_inv1.qsize(), 'parts in stage 1 inventory')

# case-by-case logs are very useful for checking the logic of the simulation
case_by_case_event_file_name = 'simulation-program-case-by-case-events-' + simulation_file_identifier + '.txt'
with open(case_by_case_event_file_name, 'wt') as fcasedata:
    lastcase_prep_time = 0  # initialize for use with first case
    # create lists for storing time interval data 
    inter_prep_times = [] # computed across cases
    waiting_time = [] # computed within each case that has begun service
    machine1_time = [] # computed within each case that has ended service
    for thiscase in caseid_list:
        # select subset of rows for thiscase and use as a Pandas data frame
        thiscase_events = event_log_df[['caseid','time','activity']][event_log_df['caseid']==thiscase]
        print(file = fcasedata)
        print('events for caseid',thiscase, file = fcasedata)
        print(thiscase_events, file = fcasedata) 
        # compute inter-arrival times between cases
        thiscase_prep_time = thiscase_events.loc[thiscase_events['activity']=='prep_part', 'time'].values[0]
        inter_prep_time = thiscase_prep_time - lastcase_prep_time
        inter_prep_times.append(inter_prep_time)
        print(file = fcasedata)
        print('time between finished parts prepped (this case minus previous case):',inter_prep_time, 'seconds', file = fcasedata)
        lastcase_prep_time  = thiscase_prep_time # save for next case in the for-loop
        # compute waiting times within this case (must have begin_service event/activity)
        if thiscase_events.loc[thiscase_events['activity']=='begin_stage1_machine'].shape[0] == 1:
            thiscase_begin_machine1 = thiscase_events.loc[thiscase_events['activity']=='begin_stage1_machine', 'time'].values[0]
            thiscase_join_queue1 = thiscase_prep_time = thiscase_events.loc[thiscase_events['activity']=='join_queue1', 'time'].values[0]
            thiscase_waiting_time = thiscase_begin_machine1 - thiscase_join_queue1
            waiting_time.append(thiscase_waiting_time)
            print('waiting time for this case (time between joining queue and beginning stage 1 machining):',thiscase_waiting_time, 'seconds', file = fcasedata)
        # compute machine time within this case (must have end_service event/activity)
        if thiscase_events.loc[thiscase_events['activity']=='end_stage1_machine'].shape[0] == 1:
            thiscase_end_machine1 = thiscase_events.loc[thiscase_events['activity']=='end_stage1_machine', 'time'].values[0]
            thiscase_machine1_time = thiscase_end_machine1 - thiscase_begin_machine1
            machine1_time.append(thiscase_machine1_time)
            print('stage 1 machine time for this case (time between beginning and ending machining):',thiscase_machine1_time, 'seconds', file = fcasedata)

print()     
print('Summary statistics for part inter-prep times:')
print('  Minimum: ',round(np.min(inter_prep_times),2), ' seconds (' ,round(np.min(inter_prep_times)/60,2), ' minutes)',sep='')  
print('  Mean:    ',round(np.average(inter_prep_times),2), ' seconds (' ,round(np.average(inter_prep_times)/60,2), ' minutes)',sep='')  
print('  Maximum: ',round(np.max(inter_prep_times),2), ' seconds (' ,round(np.max(inter_prep_times)/60,2), ' minutes)',sep='')      
print()
print('Summary statistics for part wait times:')
print('  Minimum: ',round(np.min(waiting_time),2), ' seconds (' ,round(np.min(waiting_time)/60,2), ' minutes)',sep='')  
print('  Mean:    ',round(np.average(waiting_time),2), ' seconds (' ,round(np.average(waiting_time)/60,2), ' minutes)',sep='')  
print('  Maximum: ',round(np.max(waiting_time),2), ' seconds (' ,round(np.max(waiting_time)/60,2), ' minutes)',sep='')  
print()
print('Summary statistics for stage 1 machining times:')
print('  Minimum: ',round(np.min(machine1_time),2), ' seconds (' ,round(np.min(machine1_time)/60,2), ' minutes)',sep='')  
print('  Mean:    ',round(np.average(machine1_time),2), ' seconds (' ,round(np.average(machine1_time)/60,2), ' minutes)',sep='')  
print('  Maximum: ',round(np.max(machine1_time),2), ' seconds (' ,round(np.max(machine1_time)/60,2), ' minutes)',sep='')  

print()        
print('simulation case-by-case event data written to file:',case_by_case_event_file_name)
print("this log is most useful in checking the logic of the simulation")

# Define output_table data frame for use within KNIME
# KNIME is a low-code platform for data science
output_string_key = []
output_string_value = []

output_string_key.append("Minimum inter-prep_time")
output_string_value.append(str(round(np.min(inter_prep_times),2)))
output_string_key.append("Average inter-prep_time")
output_string_value.append(str(round(np.average(inter_prep_times),2)))
output_string_key.append("Maximum inter-prep_time")
output_string_value.append(str(round(np.max(inter_prep_times),2)))

output_string_key.append("Mimimum waiting time")
output_string_value.append(str(round(np.min(waiting_time),2)))
output_string_key.append("Average waiting time")
output_string_value.append(str(round(np.average(waiting_time),2)))
output_string_key.append("Maximum waiting time")
output_string_value.append(str(round(np.max(waiting_time),2)))

output_string_key.append("Mimimum stage 1 machine time")
output_string_value.append(str(round(np.min(machine1_time),2)))
output_string_key.append("Average stage 1 machine time")
output_string_value.append(str(round(np.average(machine1_time),2)))
output_string_key.append("Maximum stage 1 machine time")
output_string_value.append(str(round(np.max(machine1_time),2)))
#output_string_key.append("Stage 1 Inventory at end of simulation")
#output_string_value.append(str(round(np.max(caseid_inv1),2)))

output_table = pd.DataFrame({"key":output_string_key, "value":output_string_value})
output_table.set_index(['key'])
# Out:
# Simulation parameter settings:
# 3 Stage 1 machines
#   Stage 1 machine time settings (in minutes)
#     minimum: 5
#     mean:    10
#     maximum: 20
# mean observed stage 1 machine times may deviate from the parameter setting
# due to censoring associated with the minimum and maximum
#
# Parts set to be prepped over 3 minute(s) on average
# Parts will be stored in stage 1 inventory if there are 20 parts in the stage 1 queue
# The simulation assumes the machine shop runs with two 8 hour shifts (16 hours of coverage per day)
# The simulation is set to run for 1 days (16 hours /960 minutes)
#
# Results after 57554 seconds (959.23 minutes, 15.99 hours):
# 350 unique parts prepped for stage 1
# 164 prepped parts joined stage 1 queue
# 186 prepped parts stored in stage 1 inventory
# 164 prepped parts that began stage 1 machining process
# 164 prepped parts that finished stage 1 machining process
# 20 parts still in stage 1 queue
# 166 parts in stage 1 inventory
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13504/1850530374.py in <module>
#      49         if thiscase_events.loc[thiscase_events['activity']=='begin_stage1_machine'].shape[0] == 1:
#      50             thiscase_begin_machine1 = thiscase_events.loc[thiscase_events['activity']=='begin_stage1_machine', 'time'].values[0]
# ---> 51             thiscase_join_queue1 = thiscase_prep_time = thiscase_events.loc[thiscase_events['activity']=='join_queue1', 'time'].values[0]
#      52             thiscase_waiting_time = thiscase_begin_machine1 - thiscase_join_queue1
#      53             waiting_time.append(thiscase_waiting_time)
#
# IndexError: index 0 is out of bounds for axis 0 with size 0
